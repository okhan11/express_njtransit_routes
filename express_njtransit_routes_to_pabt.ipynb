# %% [markdown]
# # Non-stop (express) NJ Transit routes to Port Authority Bus Terminal (PABT)

# %% [markdown]
# ## Load the raw data
# Download njtransit route data from their developer portal at https://www.njtransit.com/users/developer-tools (registration required).

# %%
ls -lrt data
# Out:
# total 175476
# -rw-r--r-- 1 ok ok     7859 Jul 27 18:21 routes.txt
# -rw-r--r-- 1 ok ok     9699 Jul 27 18:21 calendar_dates.txt
# -rw-r--r-- 1 ok ok      150 Jul 27 18:21 agency.txt
# -rw-r--r-- 1 ok ok  1071289 Jul 27 18:21 stops.txt
# -rw-r--r-- 1 ok ok 97205888 Jul 27 18:21 shapes.txt
# -rw-r--r-- 1 ok ok  2177514 Jul 27 18:21 trips.txt
# -rw-r--r-- 1 ok ok 79192311 Jul 27 18:21 stop_times.txt

# %%
import pandas as pd

# %%
trips = pd.read_csv("data/trips.txt").set_index('trip_id')
stop_times = pd.read_csv("data/stop_times.txt")
stops = pd.read_csv("data/stops.txt").set_index('stop_id')

# %%
trips
# Out:
#          route_id  service_id  \
# trip_id
# 1               1           1
# 2               1           1
# 3               1           1
# 4               1           1
# 5               1           1
# ...           ...         ...
# 34058         256           3
# 34059         256           3
# 34060         256           3
# 34061         256           3
# 34062         256           3
#
#                                              trip_headsign  direction_id  \
# trip_id
# 1        1 JERSEY CITY JOURNAL SQ VIA RIVER TERMINAL-Ex...             0
# 2        1 JERSEY CITY JOURNAL SQ VIA RIVER TERMINAL-Ex...             0
# 3        1 JERSEY CITY JOURNAL SQ VIA RIVER TERMINAL-Ex...             0
# 4        1 JERSEY CITY JOURNAL SQ VIA RIVER TERMINAL-Ex...             0
# 5        1 JERSEY CITY JOURNAL SQ VIA RIVER TERMINAL-Ex...             0
# ...                                                    ...           ...
# 34058    GO28 NEWARK BLOOMFIELD VIA BROAD ST STATION-Ex...             1
# 34059    GO28 NEWARK BLOOMFIELD VIA BROAD ST STATION-Ex...             1
# 34060    GO28 NEWARK BLOOMFIELD VIA BROAD ST STATION-Ex...             1
# 34061    GO28 NEWARK BLOOMFIELD VIA BROAD ST STATION-Ex...             1
# 34062    GO28 NEWARK BLOOMFIELD VIA BROAD ST STATION-Ex...             1
#
#          block_id  shape_id
# trip_id
# 1        001HL009         1
# 2        001HL005         1
# 3        001HL009         1
# 4        001HL007         1
# 5        001HL008         1
# ...           ...       ...
# 34058    258OG012      3487
# 34059    258OG011      3487
# 34060    258OG009      3487
# 34061    258OG010      3487
# 34062    258OG011      3487
#
# [34062 rows x 6 columns]

# %%
stop_times
# Out:
#          trip_id arrival_time departure_time  stop_id  stop_sequence  \
# 0              1     06:00:00       06:00:00     2204              1
# 1              1     06:00:56       06:00:56    27662              2
# 2              1     06:01:29       06:01:29    27663              3
# 3              1     06:02:18       06:02:18    27664              4
# 4              1     06:02:50       06:02:50    27665              5
# ...          ...          ...            ...      ...            ...
# 1823818    34062     26:39:00       26:39:00    16176             17
# 1823819    34062     26:40:40       26:40:40    40639             18
# 1823820    34062     26:41:53       26:41:53    16184             19
# 1823821    34062     26:44:28       26:44:28     1837             20
# 1823822    34062     26:46:00       26:46:00     1836             21
#
#          pickup_type  drop_off_type  shape_dist_traveled
# 0                  0              0               0.0000
# 1                  0              0               0.1860
# 2                  0              0               0.2964
# 3                  0              0               0.4602
# 4                  0              0               0.5699
# ...              ...            ...                  ...
# 1823818            0              0              11.3881
# 1823819            0              0              11.9994
# 1823820            0              0              12.4419
# 1823821            0              0              13.3850
# 1823822            0              0              13.9439
#
# [1823823 rows x 8 columns]

# %%
stops
# Out:
#          stop_code                             stop_name  stop_desc  \
# stop_id
# 162          10817                  MAIN ST AT ADAMS AVE        NaN
# 163          10837                 MAIN ST AT DELILAH RD        NaN
# 164          10811                 MAIN ST AT DELILAH RD        NaN
# 165          10820                MAIN ST AT BAYVIEW AVE        NaN
# 166          10808             MAIN ST AT CEDARCREST AVE        NaN
# ...            ...                                   ...        ...
# 44024        32691  FRANK RODGERS BLVD AT CLEVELAND AVE#        NaN
# 44025        33141             DELAWANNA AVE AT MAIN AVE        NaN
# 44026        33145                EDGEBORO ROAD AT FEDEX        NaN
# 44027        33202          AVENUE P 300'N OF WILSON AVE        NaN
# 44028        33203            DOREMUS AVE AT ROANOKE AVE        NaN
#
#           stop_lat   stop_lon  zone_id
# stop_id
# 162      39.395538 -74.519212        0
# 163      39.405069 -74.510613        0
# 164      39.404748 -74.511040        0
# 165      39.386739 -74.526992        0
# 166      39.409949 -74.506393     8195
# ...            ...        ...      ...
# 44024    40.749985 -74.157083        0
# 44025    40.835158 -74.137926        0
# 44026    40.467491 -74.397200        0
# 44027    40.714518 -74.135137        0
# 44028    40.726657 -74.122862        0
#
# [16399 rows x 6 columns]

# %% [markdown]
# ## Get PABT stop data

# %%
final_stops=stops.loc[stops['stop_name'] == 'PORT AUTHORITY BUS TERMINAL']
final_stops
# Out:
#          stop_code                    stop_name  stop_desc   stop_lat  \
# stop_id
# 3511         26229  PORT AUTHORITY BUS TERMINAL        NaN  40.756367
# 43274        31858  PORT AUTHORITY BUS TERMINAL        NaN  40.756209
#
#           stop_lon  zone_id
# stop_id
# 3511    -73.990753    12336
# 43274   -73.991001        0

# %%
final_stop=final_stops.tail(1)
final_stop_id=43274
final_stop
# Out:
#          stop_code                    stop_name  stop_desc   stop_lat  \
# stop_id
# 43274        31858  PORT AUTHORITY BUS TERMINAL        NaN  40.756209
#
#           stop_lon  zone_id
# stop_id
# 43274   -73.991001        0

# %% [markdown]
# ## Prepare bus stop data with their names and duration

# %%
stop_times_with_details=stop_times.join(stops, on='stop_id', rsuffix='_stop')
stop_times_with_details=pd.merge(stop_times_with_details, trips, on='trip_id', how='left')
stop_times_with_details
# Out:
#          trip_id arrival_time departure_time  stop_id  stop_sequence  \
# 0              1     06:00:00       06:00:00     2204              1
# 1              1     06:00:56       06:00:56    27662              2
# 2              1     06:01:29       06:01:29    27663              3
# 3              1     06:02:18       06:02:18    27664              4
# 4              1     06:02:50       06:02:50    27665              5
# ...          ...          ...            ...      ...            ...
# 1823818    34062     26:39:00       26:39:00    16176             17
# 1823819    34062     26:40:40       26:40:40    40639             18
# 1823820    34062     26:41:53       26:41:53    16184             19
# 1823821    34062     26:44:28       26:44:28     1837             20
# 1823822    34062     26:46:00       26:46:00     1836             21
#
#          pickup_type  drop_off_type  shape_dist_traveled  stop_code  \
# 0                  0              0               0.0000      18686
# 1                  0              0               0.1860      18777
# 2                  0              0               0.2964      18778
# 3                  0              0               0.4602      18779
# 4                  0              0               0.5699      18881
# ...              ...            ...                  ...        ...
# 1823818            0              0              11.3881      18299
# 1823819            0              0              11.9994      30635
# 1823820            0              0              12.4419      17139
# 1823821            0              0              13.3850      17144
# 1823822            0              0              13.9439      17207
#
#                                     stop_name  stop_desc   stop_lat  \
# 0                IVY HILL LOOP (MT VERNON PL)        NaN  40.737739
# 1                  MT. VERNON PL AT NORMAN RD        NaN  40.736909
# 2              MT. VERNON PL AT KERRIGAN BLVD        NaN  40.736290
# 3               MT. VERNON PL AT SANDFORD AVE        NaN  40.735369
# 4                       SANFORD AVE AT IVY ST        NaN  40.736550
# ...                                       ...        ...        ...
# 1823818  BLOOMFIELD AVENUE LIGHT RAIL STATION        NaN  40.765649
# 1823819       BLOOMFIELD AVE AT NORTH 11TH ST        NaN  40.773417
# 1823820            BLOOMFIELD AVE AT GROVE ST        NaN  40.779060
# 1823821     BLOOMFIELD AVE AT MUNICIPAL PLAZA        NaN  40.791580
# 1823822             CONGER ST AT GLENWOOD AVE        NaN  40.791599
#
#           stop_lon  zone_id  route_id  service_id  \
# 0       -74.245290        0         1           1
# 1       -74.242423        0         1           1
# 2       -74.240411        0         1           1
# 3       -74.237433        0         1           1
# 4       -74.236463        0         1           1
# ...            ...      ...       ...         ...
# 1823818 -74.179872      336       256           3
# 1823819 -74.185161        0       256           3
# 1823820 -74.189132        0       256           3
# 1823821 -74.196382        0       256           3
# 1823822 -74.199071        0       256           3
#
#                                              trip_headsign  direction_id  \
# 0        1 JERSEY CITY JOURNAL SQ VIA RIVER TERMINAL-Ex...             0
# 1        1 JERSEY CITY JOURNAL SQ VIA RIVER TERMINAL-Ex...             0
# 2        1 JERSEY CITY JOURNAL SQ VIA RIVER TERMINAL-Ex...             0
# 3        1 JERSEY CITY JOURNAL SQ VIA RIVER TERMINAL-Ex...             0
# 4        1 JERSEY CITY JOURNAL SQ VIA RIVER TERMINAL-Ex...             0
# ...                                                    ...           ...
# 1823818  GO28 NEWARK BLOOMFIELD VIA BROAD ST STATION-Ex...             1
# 1823819  GO28 NEWARK BLOOMFIELD VIA BROAD ST STATION-Ex...             1
# 1823820  GO28 NEWARK BLOOMFIELD VIA BROAD ST STATION-Ex...             1
# 1823821  GO28 NEWARK BLOOMFIELD VIA BROAD ST STATION-Ex...             1
# 1823822  GO28 NEWARK BLOOMFIELD VIA BROAD ST STATION-Ex...             1
#
#          block_id  shape_id
# 0        001HL009         1
# 1        001HL009         1
# 2        001HL009         1
# 3        001HL009         1
# 4        001HL009         1
# ...           ...       ...
# 1823818  258OG011      3487
# 1823819  258OG011      3487
# 1823820  258OG011      3487
# 1823821  258OG011      3487
# 1823822  258OG011      3487
#
# [1823823 rows x 20 columns]

# %% [markdown]
# ### Compile bus stops with one stop to PABT
#
# * Get `stop_sequence` for each `trip_id` where `stop_id=43274` (PABT)
# * For each `trip_id`, get `stop_sequence-1`

# %%
from dateutil.parser import parse as dt_parse

nonstop_stops=None

for trip_id, trip_stops in stop_times_with_details.groupby('trip_id'):
    if final_stop_id not in trip_stops['stop_id'].values:
        continue
    # Unnecessary to compute it for every row
    #trip_stops['arrival_time']=pd.to_datetime(trip_stops['arrival_time'], format='%H:%M:%S', errors='coerce')
    #trip_stops['departure_time']=pd.to_datetime(trip_stops['departure_time'], format='%H:%M:%S', errors='coerce')
    start=trip_stops.tail(3).head(1)
    stop=trip_stops.tail(1)
    try:
        start['duration_in_minutes']=(dt_parse(stop['arrival_time'].iloc[0])-dt_parse(start['departure_time'].iloc[0])).total_seconds()/60
    except:
        continue # skip
    if nonstop_stops is None:
        nonstop_stops = start
    else:
        nonstop_stops = pd.concat([nonstop_stops, start])

# %%
display(nonstop_stops.query('departure_time > "06:00:00" and departure_time < "10:00:00"'))
# Out:
#         trip_id arrival_time departure_time  stop_id  stop_sequence  \
# 59563      1064     06:37:00       06:37:00    12120             40
# 59605      1065     07:07:00       07:07:00    12120             40
# 59647      1066     07:37:00       07:37:00    12120             40
# 59689      1067     08:07:00       08:07:00    12120             40
# 59731      1068     08:37:00       08:37:00    12120             40
# ...         ...          ...            ...      ...            ...
# 834541    17388     06:25:00       06:25:00    39684              1
# 834544    17389     06:53:00       06:53:00    39684              1
# 834547    17390     07:08:00       07:08:00    39684              1
# 834550    17391     07:29:00       07:29:00    39684              1
# 834553    17392     08:07:00       08:07:00    39684              1
#
#         pickup_type  drop_off_type  shape_dist_traveled  stop_code  \
# 59563             0              0               9.3388      18888
# 59605             0              0               9.3388      18888
# 59647             0              0               9.3388      18888
# 59689             0              0               9.3388      18888
# 59731             0              0               9.3388      18888
# ...             ...            ...                  ...        ...
# 834541            0              0               0.0000      27848
# 834544            0              0               0.0000      27848
# 834547            0              0               0.0000      27848
# 834550            0              0               0.0000      27848
# 834553            0              0               0.0000      27848
#
#                                 stop_name  ...   stop_lat   stop_lon  zone_id  \
# 59563   NORTH AREA TRANS CENTER - PORT ST  ...  40.707739 -74.160031       73
# 59605   NORTH AREA TRANS CENTER - PORT ST  ...  40.707739 -74.160031       73
# 59647   NORTH AREA TRANS CENTER - PORT ST  ...  40.707739 -74.160031       73
# 59689   NORTH AREA TRANS CENTER - PORT ST  ...  40.707739 -74.160031       73
# 59731   NORTH AREA TRANS CENTER - PORT ST  ...  40.707739 -74.160031       73
# ...                                   ...  ...        ...        ...      ...
# 834541      WAYNE ROUTE 23 TRANSIT CENTER  ...  40.900867 -74.255823        0
# 834544      WAYNE ROUTE 23 TRANSIT CENTER  ...  40.900867 -74.255823        0
# 834547      WAYNE ROUTE 23 TRANSIT CENTER  ...  40.900867 -74.255823        0
# 834550      WAYNE ROUTE 23 TRANSIT CENTER  ...  40.900867 -74.255823        0
# 834553      WAYNE ROUTE 23 TRANSIT CENTER  ...  40.900867 -74.255823        0
#
#         route_id  service_id            trip_headsign direction_id  block_id  \
# 59563          3           1  107 NEW YORK-Exact Fare            0  107HL002
# 59605          3           1  107 NEW YORK-Exact Fare            0  107HL005
# 59647          3           1  107 NEW YORK-Exact Fare            0  107HL004
# 59689          3           1  107 NEW YORK-Exact Fare            0  107HL006
# 59731          3           1  107 NEW YORK-Exact Fare            0  107HL001
# ...          ...         ...                      ...          ...       ...
# 834541        95           3     324 NEW YORK EXPRESS            0  191WY007
# 834544        95           3     324 NEW YORK EXPRESS            0  194WY002
# 834547        95           3     324 NEW YORK EXPRESS            0  194WY007
# 834550        95           3     324 NEW YORK EXPRESS            0  194WY020
# 834553        95           3     324 NEW YORK EXPRESS            0  191WY026
#
#        shape_id  duration_in_minutes
# 59563        74                 20.0
# 59605        74                 20.0
# 59647        74                 20.0
# 59689        74                 20.0
# 59731        74                 20.0
# ...         ...                  ...
# 834541     1566                 38.0
# 834544     1566                 38.0
# 834547     1566                 38.0
# 834550     1566                 38.0
# 834553     1566                 38.0
#
# [2394 rows x 21 columns]

# %%
express_routes_by_stop=nonstop_stops.pivot_table(index='stop_name', values=['duration_in_minutes', 'stop_lat', 'stop_lon'], aggfunc='max')
express_routes_by_stop
# Out:
#                                                    duration_in_minutes  \
# stop_name
# 30TH ST AT BERGENLINE AVE                                     7.866667
# 30TH ST AT PLEASANT AVE                                      26.183333
# 60TH ST AT PARK AVE                                          18.800000
# AMERICAN DREAM                                               26.000000
# BAYWAY AVE AT MCKINLEY ST                                    41.000000
# BOULEVARD EAST AT NORTH MARGINAL RD                          24.550000
# BRICK TWP PARK RIDE                                          80.000000
# BROAD AVE AT HOMESTEAD AVE                                   32.000000
# BROAD AVE AT SHEFFIELD AVE                                   30.566667
# BUS LANES (RAYMOND BLVD SIDE)                                30.000000
# CENTURY RD AT ESSEX RD                                       33.916667
# CENTURY RD AT SADDLE RIVER RD                                33.833333
# CHALLENGER RD 346' N OF EMERSON ST.                          22.550000
# DEGRAW AVE AT FRANK W. BURR BLVD                             24.216667
# E RIDGEWOOD AVE AT CHADWICK DR#                              43.800000
# EASTERN PKWY AT 15TH AVE                                     33.366667
# FRANK W. BURR BLVD 590'N OF GLENWOOD AVE.                    37.400000
# GARDEN STATE PARKWAY UNDER RIDGEWOOD AVE                     41.000000
# GSP EXIT 120 PARK & RIDE                                     46.000000
# HILLSIDE AVE AT MUNN AVE                                     50.883333
# JERSEY GARDENS - MAIN ENTRANCE                               59.000000
# LINCOLN HARBOR                                               12.000000
# LINWOOD AVE AT PARK PL                                       29.800000
# LLOYD RD AT LINE RD                                          58.000000
# MEADOWLANDS PKWY 265'S OF TENTH ST                           18.266667
# N BROAD ST AT HOLLYWOOD AVE                                  56.000000
# NJ 18 AT EGGERS ST                                           44.000000
# NJ ROUTE 208 AT MORLOT AVE                                   33.000000
# NORTH & DOWD AVES                                            52.000000
# NORTH AREA TRANS CENTER - PORT ST                            35.000000
# NORTH AVE 250' W OF JOHN ST.                                 49.850000
# NORTH BERGEN PARK/RIDE LOT AT TERMINAL BUILDING B            39.416667
# OLD BRIDGE PARK & RIDE (NORTHBOUND)                          45.000000
# PARK AVE AT 34TH ST                                          19.100000
# PATERSON PLANK RD AT GOTHAM PARKWAY                          25.833333
# PATERSON PLANK RD AT NJ TPKE EXIT 16E                        23.750000
# POLIFLY RD AT CHARLES ST                                     29.516667
# RINGWOOD PARK & RIDE                                         56.000000
# RIVER DR AT KENSINGTON TER                                   31.050000
# RIVERVIEW DR AT RT 46                                        33.000000
# ROOSEVELT AVE AT HARRISON AVE                                61.000000
# RT-3 AT CLIFTON COMMONS ENTRANCE                             26.000000
# RT-4 AT MARGARET ST                                          36.116667
# RUTHERFORD AVE AT POLITO AVE                                 38.000000
# SAYREVILLE PARK & RIDE GSP RAMP                              41.000000
# SIX FLAGS PARKWAY AT CORAL #3                               109.900000
# TEANECK RD AT EAST WINANT AVE#                               24.083333
# TEANECK RD AT LIBERTY RD                                     33.000000
# TOMS RIVER PARK & RIDE                                       95.000000
# UNION BLVD 320'S OF WILSON AVE                               34.350000
# US-22 560'W OF BALL AVE                                      45.333333
# US-46 112' W of TEANECK RD #                                 30.450000
# VINCE LOMBARDI PARK & RIDE                                   32.000000
# WASHINGTON AVE AT ROAD A                                     24.833333
# WAYNE ROUTE 23 TRANSIT CENTER                                38.000000
# WILLOW AVE AT 19TH ST                                        19.500000
# WILLOWBROOK PARK & RIDE                                      55.000000
#
#                                                     stop_lat   stop_lon
# stop_name
# 30TH ST AT BERGENLINE AVE                          40.770998 -74.029591
# 30TH ST AT PLEASANT AVE                            40.768910 -74.024723
# 60TH ST AT PARK AVE                                40.785590 -74.009440
# AMERICAN DREAM                                     40.810789 -74.067143
# BAYWAY AVE AT MCKINLEY ST                          40.644510 -74.212380
# BOULEVARD EAST AT NORTH MARGINAL RD                40.768129 -74.021441
# BRICK TWP PARK RIDE                                40.098968 -74.141133
# BROAD AVE AT HOMESTEAD AVE                         40.845278 -73.999861
# BROAD AVE AT SHEFFIELD AVE                         40.873980 -73.979213
# BUS LANES (RAYMOND BLVD SIDE)                      40.734538 -74.163281
# CENTURY RD AT ESSEX RD                             40.932238 -74.076713
# CENTURY RD AT SADDLE RIVER RD                      40.944728 -74.100084
# CHALLENGER RD 346' N OF EMERSON ST.                40.848959 -74.013313
# DEGRAW AVE AT FRANK W. BURR BLVD                   40.871549 -74.007183
# E RIDGEWOOD AVE AT CHADWICK DR#                    40.966508 -74.071361
# EASTERN PKWY AT 15TH AVE                           40.741208 -74.214883
# FRANK W. BURR BLVD 590'N OF GLENWOOD AVE.          40.872519 -74.004633
# GARDEN STATE PARKWAY UNDER RIDGEWOOD AVE           40.963979 -74.065833
# GSP EXIT 120 PARK & RIDE                           40.432429 -74.251681
# HILLSIDE AVE AT MUNN AVE                           40.698087 -74.220690
# JERSEY GARDENS - MAIN ENTRANCE                     40.661798 -74.170930
# LINCOLN HARBOR                                     40.759878 -74.022280
# LINWOOD AVE AT PARK PL                             40.862279 -73.967644
# LLOYD RD AT LINE RD                                40.417259 -74.212923
# MEADOWLANDS PKWY 265'S OF TENTH ST                 40.793378 -74.070333
# N BROAD ST AT HOLLYWOOD AVE                        40.694879 -74.215862
# NJ 18 AT EGGERS ST                                 40.468439 -74.407851
# NJ ROUTE 208 AT MORLOT AVE                         40.931819 -74.112173
# NORTH & DOWD AVES                                  40.676478 -74.195112
# NORTH AREA TRANS CENTER - PORT ST                  40.707739 -74.160031
# NORTH AVE 250' W OF JOHN ST.                       40.657529 -74.293723
# NORTH BERGEN PARK/RIDE LOT AT TERMINAL BUILDING B  40.776698 -74.042811
# OLD BRIDGE PARK & RIDE (NORTHBOUND)                40.446218 -74.299461
# PARK AVE AT 34TH ST                                40.770537 -74.023221
# PATERSON PLANK RD AT GOTHAM PARKWAY                40.821189 -74.069941
# PATERSON PLANK RD AT NJ TPKE EXIT 16E              40.785269 -74.050902
# POLIFLY RD AT CHARLES ST                           40.876438 -74.058812
# RINGWOOD PARK & RIDE                               41.088639 -74.266391
# RIVER DR AT KENSINGTON TER                         40.839716 -74.125656
# RIVERVIEW DR AT RT 46                              40.897628 -74.237583
# ROOSEVELT AVE AT HARRISON AVE                      40.590499 -74.228016
# RT-3 AT CLIFTON COMMONS ENTRANCE                   40.829100 -74.137471
# RT-4 AT MARGARET ST                                40.891740 -74.007502
# RUTHERFORD AVE AT POLITO AVE                       40.810340 -74.103440
# SAYREVILLE PARK & RIDE GSP RAMP                    40.477460 -74.298472
# SIX FLAGS PARKWAY AT CORAL #3                      40.139639 -74.443602
# TEANECK RD AT EAST WINANT AVE#                     40.849268 -74.021641
# TEANECK RD AT LIBERTY RD                           40.911787 -73.997883
# TOMS RIVER PARK & RIDE                             39.951668 -74.205201
# UNION BLVD 320'S OF WILSON AVE                     40.898689 -74.220353
# US-22 560'W OF BALL AVE                            40.690379 -74.291013
# US-46 112' W of TEANECK RD #                       40.848449 -74.022123
# VINCE LOMBARDI PARK & RIDE                         40.827069 -74.028153
# WASHINGTON AVE AT ROAD A                           40.818599 -74.065122
# WAYNE ROUTE 23 TRANSIT CENTER                      40.900867 -74.255823
# WILLOW AVE AT 19TH ST                              40.759809 -74.027751
# WILLOWBROOK PARK & RIDE                            40.885289 -74.258432

# %% [markdown]
# ## Plot data in Google Maps

# %% [markdown]
# 1. Dump into a .csv

# %%
express_routes_by_stop.to_csv('express_routes_by_stop.csv', index=True)

# %% [markdown]
# 2. Copy map https://www.google.com/maps/d/edit?mid=1gbrVIEyaYfsTAUQjFQ27qrA-mPYEXhw&ll=40.70844175474683%2C-74.06476546082344&z=10
# 3. Import data from `express_routes_by_stop.csv`, using the settings below:
