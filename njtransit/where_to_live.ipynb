# %%
ls -lrt data
# Out:
# total 175476
# -rw-r--r-- 1 ok ok      150 Jul 13 11:38 agency.txt
# -rw-r--r-- 1 ok ok  2177514 Jul 13 11:38 trips.txt
# -rw-r--r-- 1 ok ok 79192311 Jul 13 11:38 stop_times.txt
# -rw-r--r-- 1 ok ok  1071289 Jul 13 11:38 stops.txt
# -rw-r--r-- 1 ok ok 97205888 Jul 13 11:38 shapes.txt
# -rw-r--r-- 1 ok ok     7859 Jul 13 11:38 routes.txt
# -rw-r--r-- 1 ok ok     9699 Jul 13 11:38 calendar_dates.txt

# %%
import pandas as pd

# %%
agency = pd.read_csv("data/agency.txt")
trips = pd.read_csv("data/trips.txt").set_index('trip_id')
stop_times = pd.read_csv("data/stop_times.txt")
stops = pd.read_csv("data/stops.txt").set_index('stop_id')
shapes = pd.read_csv("data/shapes.txt")
routes = pd.read_csv("data/routes.txt")
calendar_dates = pd.read_csv("data/calendar_dates.txt")

# %%
agency
# Out:
#   agency_id     agency_name                 agency_url   agency_timezone  \
# 0       NJB  NJ TRANSIT BUS  http://www.njtransit.com/  America/New_York
#
#   agency_lang  agency_phone
# 0          en           NaN

# %%
trips
# Out:
#          route_id  service_id  \
# trip_id
# 1               1           1
# 2               1           1
# 3               1           1
# 4               1           1
# 5               1           1
# ...           ...         ...
# 34058         256           3
# 34059         256           3
# 34060         256           3
# 34061         256           3
# 34062         256           3
#
#                                              trip_headsign  direction_id  \
# trip_id
# 1        1 JERSEY CITY JOURNAL SQ VIA RIVER TERMINAL-Ex...             0
# 2        1 JERSEY CITY JOURNAL SQ VIA RIVER TERMINAL-Ex...             0
# 3        1 JERSEY CITY JOURNAL SQ VIA RIVER TERMINAL-Ex...             0
# 4        1 JERSEY CITY JOURNAL SQ VIA RIVER TERMINAL-Ex...             0
# 5        1 JERSEY CITY JOURNAL SQ VIA RIVER TERMINAL-Ex...             0
# ...                                                    ...           ...
# 34058    GO28 NEWARK BLOOMFIELD VIA BROAD ST STATION-Ex...             1
# 34059    GO28 NEWARK BLOOMFIELD VIA BROAD ST STATION-Ex...             1
# 34060    GO28 NEWARK BLOOMFIELD VIA BROAD ST STATION-Ex...             1
# 34061    GO28 NEWARK BLOOMFIELD VIA BROAD ST STATION-Ex...             1
# 34062    GO28 NEWARK BLOOMFIELD VIA BROAD ST STATION-Ex...             1
#
#          block_id  shape_id
# trip_id
# 1        001HL009         1
# 2        001HL005         1
# 3        001HL009         1
# 4        001HL007         1
# 5        001HL008         1
# ...           ...       ...
# 34058    258OG012      3487
# 34059    258OG011      3487
# 34060    258OG009      3487
# 34061    258OG010      3487
# 34062    258OG011      3487
#
# [34062 rows x 6 columns]

# %%
stop_times
# Out:
#          trip_id arrival_time departure_time  stop_id  stop_sequence  \
# 0              1     06:00:00       06:00:00     2204              1
# 1              1     06:00:56       06:00:56    27662              2
# 2              1     06:01:29       06:01:29    27663              3
# 3              1     06:02:18       06:02:18    27664              4
# 4              1     06:02:50       06:02:50    27665              5
# ...          ...          ...            ...      ...            ...
# 1823818    34062     26:39:00       26:39:00    16176             17
# 1823819    34062     26:40:40       26:40:40    40639             18
# 1823820    34062     26:41:53       26:41:53    16184             19
# 1823821    34062     26:44:28       26:44:28     1837             20
# 1823822    34062     26:46:00       26:46:00     1836             21
#
#          pickup_type  drop_off_type  shape_dist_traveled
# 0                  0              0               0.0000
# 1                  0              0               0.1860
# 2                  0              0               0.2964
# 3                  0              0               0.4602
# 4                  0              0               0.5699
# ...              ...            ...                  ...
# 1823818            0              0              11.3881
# 1823819            0              0              11.9994
# 1823820            0              0              12.4419
# 1823821            0              0              13.3850
# 1823822            0              0              13.9439
#
# [1823823 rows x 8 columns]

# %%
stops
# Out:
#          stop_code                             stop_name  stop_desc  \
# stop_id
# 162          10817                  MAIN ST AT ADAMS AVE        NaN
# 163          10837                 MAIN ST AT DELILAH RD        NaN
# 164          10811                 MAIN ST AT DELILAH RD        NaN
# 165          10820                MAIN ST AT BAYVIEW AVE        NaN
# 166          10808             MAIN ST AT CEDARCREST AVE        NaN
# ...            ...                                   ...        ...
# 44024        32691  FRANK RODGERS BLVD AT CLEVELAND AVE#        NaN
# 44025        33141             DELAWANNA AVE AT MAIN AVE        NaN
# 44026        33145                EDGEBORO ROAD AT FEDEX        NaN
# 44027        33202          AVENUE P 300'N OF WILSON AVE        NaN
# 44028        33203            DOREMUS AVE AT ROANOKE AVE        NaN
#
#           stop_lat   stop_lon  zone_id
# stop_id
# 162      39.395538 -74.519212        0
# 163      39.405069 -74.510613        0
# 164      39.404748 -74.511040        0
# 165      39.386739 -74.526992        0
# 166      39.409949 -74.506393     8195
# ...            ...        ...      ...
# 44024    40.749985 -74.157083        0
# 44025    40.835158 -74.137926        0
# 44026    40.467491 -74.397200        0
# 44027    40.714518 -74.135137        0
# 44028    40.726657 -74.122862        0
#
# [16399 rows x 6 columns]

# %%
shapes
# Out:
#          shape_id  shape_pt_lat  shape_pt_lon  shape_pt_sequence  \
# 0               1     40.737739    -74.245290                  1
# 1               1     40.737780    -74.245373                  2
# 2               1     40.737868    -74.245339                  3
# 3               1     40.737736    -74.244892                  4
# 4               1     40.737566    -74.244395                  5
# ...           ...           ...           ...                ...
# 2607160      3487     40.793578    -74.199955                706
# 2607161      3487     40.793487    -74.199985                707
# 2607162      3487     40.793336    -74.199943                708
# 2607163      3487     40.791947    -74.199382                709
# 2607164      3487     40.791668    -74.199045                710
#
#          shape_dist_traveled
# 0                     0.0000
# 1                     0.0051
# 2                     0.0114
# 3                     0.0364
# 4                     0.0650
# ...                      ...
# 2607160              13.8004
# 2607161              13.8066
# 2607162              13.8172
# 2607163              13.9178
# 2607164              13.9439
#
# [2607165 rows x 5 columns]

# %%
routes
# Out:
#      route_id agency_id route_short_name  route_long_name  route_type  \
# 0           1       NJB                1              NaN           3
# 1           2       NJB               10              NaN           3
# 2           3       NJB              107              NaN           3
# 3           4       NJB              108              NaN           3
# 4           5       NJB               11              NaN           3
# ..        ...       ...              ...              ...         ...
# 251       252       NJB              AC1              NaN           3
# 252       253       NJB              AC3              NaN           3
# 253       254       NJB             AC4B              NaN           3
# 254       255       NJB             GO25              NaN           3
# 255       256       NJB             GO28              NaN           3
#
#      route_url  route_color
# 0          NaN            0
# 1          NaN            0
# 2          NaN            0
# 3          NaN            0
# 4          NaN            0
# ..         ...          ...
# 251        NaN            0
# 252        NaN            0
# 253        NaN            0
# 254        NaN            0
# 255        NaN            0
#
# [256 rows x 7 columns]

# %%
calendar_dates
# Out:
#      service_id      date  exception_type
# 0             1  20230715               1
# 1             1  20230722               1
# 2             1  20230729               1
# 3             1  20230805               1
# 4             1  20230812               1
# ..          ...       ...             ...
# 719          20  20230829               1
# 720          20  20230830               1
# 721          20  20230831               1
# 722          20  20230901               1
# 723          20  20230904               1
#
# [724 rows x 3 columns]

# %%
stops.loc[stops['stop_name'].str.startswith("GARDEN STATE PARKWAY UNDER RIDGEWOOD AVE")]
# Out:
#          stop_code                                 stop_name  stop_desc  \
# stop_id
# 26294        12973  GARDEN STATE PARKWAY UNDER RIDGEWOOD AVE        NaN
#
#           stop_lat   stop_lon  zone_id
# stop_id
# 26294    40.963979 -74.065833        0

# %%
stop_times.loc[stop_times['stop_id'] == 26294]
# Out:
#         trip_id arrival_time departure_time  stop_id  stop_sequence  \
# 438645     9581     06:27:00       06:27:00    26294             20
# 438667     9582     07:50:00       07:50:00    26294             20
# 445874     9670     05:20:00       05:20:00    26294             26
# 445902     9671     05:35:00       05:35:00    26294             26
# 445930     9672     05:50:00       05:50:00    26294             26
# ...         ...          ...            ...      ...            ...
# 471301    10061     19:11:00       19:11:00    26294              4
# 471330    10062     19:31:00       19:31:00    26294              4
# 471359    10063     20:01:00       20:01:00    26294              4
# 471388    10064     20:31:00       20:31:00    26294              4
# 471417    10065     21:26:00       21:26:00    26294              4
#
#         pickup_type  drop_off_type  shape_dist_traveled
# 438645            0              0               4.3112
# 438667            0              0               4.3112
# 445874            0              0               6.4483
# 445902            0              0               6.4483
# 445930            0              0               6.4483
# ...             ...            ...                  ...
# 471301            0              0              22.0824
# 471330            0              0              22.0824
# 471359            0              0              22.0824
# 471388            0              0              22.0824
# 471417            0              0              22.0824
#
# [75 rows x 8 columns]

# %%
trips.loc[trips.index==9581]
# Out:
#          route_id  service_id              trip_headsign  direction_id  \
# trip_id
# 9581           51           4  165P NEW YORK PARKWAY EXP             0
#
#          block_id  shape_id
# trip_id
# 9581     168WW008       788

# %%
trips.loc[trips.route_id==51]
# Out:
#          route_id  service_id                           trip_headsign  \
# trip_id
# 9332           51           1        165 NEW YORK LOCAL VIA BLVD EAST
# 9333           51           1        165 NEW YORK LOCAL VIA BLVD EAST
# 9334           51           1        165 NEW YORK LOCAL VIA BLVD EAST
# 9335           51           1        165 NEW YORK LOCAL VIA BLVD EAST
# 9336           51           1        165 NEW YORK LOCAL VIA BLVD EAST
# ...           ...         ...                                     ...
# 10066          51           5  165RF RT 4 EXPRESS FOREST AVE WESTWOOD
# 10067          51           5  165RF RT 4 EXPRESS FOREST AVE WESTWOOD
# 10068          51           5  165RF RT 4 EXPRESS FOREST AVE WESTWOOD
# 10069          51           5  165RF RT 4 EXPRESS FOREST AVE WESTWOOD
# 10070          51           5  165RF RT 4 EXPRESS FOREST AVE WESTWOOD
#
#          direction_id  block_id  shape_id
# trip_id
# 9332                0  165WW004       765
# 9333                0  165WW002       765
# 9334                0  165WW008       765
# 9335                0  165WW010       765
# 9336                0  165WW006       766
# ...               ...       ...       ...
# 10066               1  165WW056       843
# 10067               1  165WW063       843
# 10068               1  168WW023       843
# 10069               1  165WW071       843
# 10070               1  165WW042       843
#
# [739 rows x 6 columns]

# %%
stop_times.loc[stop_times['trip_id']==9581]
# Out:
#         trip_id arrival_time departure_time  stop_id  stop_sequence  \
# 438626     9581     06:12:00       06:12:00     1423              1
# 438627     9581     06:13:07       06:13:07    43757              2
# 438628     9581     06:13:55       06:13:55    43754              3
# 438629     9581     06:14:59       06:14:59    43839              4
# 438630     9581     06:15:10       06:15:10     1263              5
# 438631     9581     06:15:45       06:15:45     1264              6
# 438632     9581     06:16:31       06:16:31     1265              7
# 438633     9581     06:17:07       06:17:07    43024              8
# 438634     9581     06:17:45       06:17:45     1267              9
# 438635     9581     06:18:33       06:18:33     1280             10
# 438636     9581     06:19:00       06:19:00     1277             11
# 438637     9581     06:20:28       06:20:28     1278             12
# 438638     9581     06:22:17       06:22:17     1279             13
# 438639     9581     06:22:55       06:22:55    42959             14
# 438640     9581     06:23:30       06:23:30    18228             15
# 438641     9581     06:24:09       06:24:09    26235             16
# 438642     9581     06:24:27       06:24:27    43709             17
# 438643     9581     06:25:02       06:25:02    41397             18
# 438644     9581     06:26:30       06:26:30    37234             19
# 438645     9581     06:27:00       06:27:00    26294             20
# 438646     9581     07:07:42       07:07:42    43310             21
# 438647     9581     07:08:00       07:08:00    43274             22
#
#         pickup_type  drop_off_type  shape_dist_traveled
# 438626            0              0               0.0000
# 438627            0              0               0.3563
# 438628            0              0               0.6133
# 438629            0              0               0.9580
# 438630            0              0               1.0170
# 438631            0              0               1.2051
# 438632            0              0               1.4481
# 438633            0              0               1.6436
# 438634            0              0               1.8434
# 438635            0              0               2.1002
# 438636            0              0               2.2470
# 438637            0              0               2.6261
# 438638            0              0               3.0951
# 438639            0              0               3.2595
# 438640            0              0               3.4085
# 438641            0              0               3.5777
# 438642            0              0               3.6534
# 438643            0              0               3.8059
# 438644            0              0               4.1809
# 438645            0              0               4.3112
# 438646            1              0              27.2854
# 438647            0              0              27.4591

# %% [markdown]
# # Nonstop to PABT

# %%
final_stops=stops.loc[stops['stop_name'] == "PORT AUTHORITY BUS TERMINAL"]
final_stops
# Out:
#          stop_code                    stop_name  stop_desc   stop_lat  \
# stop_id
# 3511         26229  PORT AUTHORITY BUS TERMINAL        NaN  40.756367
# 43274        31858  PORT AUTHORITY BUS TERMINAL        NaN  40.756209
#
#           stop_lon  zone_id
# stop_id
# 3511    -73.990753    12336
# 43274   -73.991001        0

# %%
final_stop=final_stops.tail(1)
final_stop_id=43274
final_stop
# Out:
#          stop_code                    stop_name  stop_desc   stop_lat  \
# stop_id
# 43274        31858  PORT AUTHORITY BUS TERMINAL        NaN  40.756209
#
#           stop_lon  zone_id
# stop_id
# 43274   -73.991001        0

# %%
stop_times_with_details=stop_times.join(stops, on='stop_id', rsuffix="_stop")
stop_times_with_details=pd.merge(stop_times_with_details, trips, on='trip_id', how='left')
stop_times_with_details
# Out:
#          trip_id arrival_time departure_time  stop_id  stop_sequence  \
# 0              1     06:00:00       06:00:00     2204              1
# 1              1     06:00:56       06:00:56    27662              2
# 2              1     06:01:29       06:01:29    27663              3
# 3              1     06:02:18       06:02:18    27664              4
# 4              1     06:02:50       06:02:50    27665              5
# ...          ...          ...            ...      ...            ...
# 1823818    34062     26:39:00       26:39:00    16176             17
# 1823819    34062     26:40:40       26:40:40    40639             18
# 1823820    34062     26:41:53       26:41:53    16184             19
# 1823821    34062     26:44:28       26:44:28     1837             20
# 1823822    34062     26:46:00       26:46:00     1836             21
#
#          pickup_type  drop_off_type  shape_dist_traveled  stop_code  \
# 0                  0              0               0.0000      18686
# 1                  0              0               0.1860      18777
# 2                  0              0               0.2964      18778
# 3                  0              0               0.4602      18779
# 4                  0              0               0.5699      18881
# ...              ...            ...                  ...        ...
# 1823818            0              0              11.3881      18299
# 1823819            0              0              11.9994      30635
# 1823820            0              0              12.4419      17139
# 1823821            0              0              13.3850      17144
# 1823822            0              0              13.9439      17207
#
#                                     stop_name  stop_desc   stop_lat  \
# 0                IVY HILL LOOP (MT VERNON PL)        NaN  40.737739
# 1                  MT. VERNON PL AT NORMAN RD        NaN  40.736909
# 2              MT. VERNON PL AT KERRIGAN BLVD        NaN  40.736290
# 3               MT. VERNON PL AT SANDFORD AVE        NaN  40.735369
# 4                       SANFORD AVE AT IVY ST        NaN  40.736550
# ...                                       ...        ...        ...
# 1823818  BLOOMFIELD AVENUE LIGHT RAIL STATION        NaN  40.765649
# 1823819       BLOOMFIELD AVE AT NORTH 11TH ST        NaN  40.773417
# 1823820            BLOOMFIELD AVE AT GROVE ST        NaN  40.779060
# 1823821     BLOOMFIELD AVE AT MUNICIPAL PLAZA        NaN  40.791580
# 1823822             CONGER ST AT GLENWOOD AVE        NaN  40.791599
#
#           stop_lon  zone_id  route_id  service_id  \
# 0       -74.245290        0         1           1
# 1       -74.242423        0         1           1
# 2       -74.240411        0         1           1
# 3       -74.237433        0         1           1
# 4       -74.236463        0         1           1
# ...            ...      ...       ...         ...
# 1823818 -74.179872      336       256           3
# 1823819 -74.185161        0       256           3
# 1823820 -74.189132        0       256           3
# 1823821 -74.196382        0       256           3
# 1823822 -74.199071        0       256           3
#
#                                              trip_headsign  direction_id  \
# 0        1 JERSEY CITY JOURNAL SQ VIA RIVER TERMINAL-Ex...             0
# 1        1 JERSEY CITY JOURNAL SQ VIA RIVER TERMINAL-Ex...             0
# 2        1 JERSEY CITY JOURNAL SQ VIA RIVER TERMINAL-Ex...             0
# 3        1 JERSEY CITY JOURNAL SQ VIA RIVER TERMINAL-Ex...             0
# 4        1 JERSEY CITY JOURNAL SQ VIA RIVER TERMINAL-Ex...             0
# ...                                                    ...           ...
# 1823818  GO28 NEWARK BLOOMFIELD VIA BROAD ST STATION-Ex...             1
# 1823819  GO28 NEWARK BLOOMFIELD VIA BROAD ST STATION-Ex...             1
# 1823820  GO28 NEWARK BLOOMFIELD VIA BROAD ST STATION-Ex...             1
# 1823821  GO28 NEWARK BLOOMFIELD VIA BROAD ST STATION-Ex...             1
# 1823822  GO28 NEWARK BLOOMFIELD VIA BROAD ST STATION-Ex...             1
#
#          block_id  shape_id
# 0        001HL009         1
# 1        001HL009         1
# 2        001HL009         1
# 3        001HL009         1
# 4        001HL009         1
# ...           ...       ...
# 1823818  258OG011      3487
# 1823819  258OG011      3487
# 1823820  258OG011      3487
# 1823821  258OG011      3487
# 1823822  258OG011      3487
#
# [1823823 rows x 20 columns]

# %%
stop_times_with_details.loc[stop_times_with_details['stop_id']==final_stop_id]
# Out:
#         trip_id arrival_time departure_time  stop_id  stop_sequence  \
# 59565      1064     06:57:00       06:57:00    43274             42
# 59607      1065     07:27:00       07:27:00    43274             42
# 59649      1066     07:57:00       07:57:00    43274             42
# 59691      1067     08:27:00       08:27:00    43274             42
# 59733      1068     08:57:00       08:57:00    43274             42
# ...         ...          ...            ...      ...            ...
# 858661    17929     21:20:00       21:20:00    43274              2
# 858663    17930     22:19:00       22:19:00    43274              2
# 858665    17931     23:19:00       23:19:00    43274              2
# 858695    17946     19:26:00       19:26:00    43274              2
# 858697    17947     21:46:00       21:46:00    43274              2
#
#         pickup_type  drop_off_type  shape_dist_traveled  stop_code  \
# 59565             0              0              23.1951      31858
# 59607             0              0              23.1951      31858
# 59649             0              0              23.1951      31858
# 59691             0              0              23.1951      31858
# 59733             0              0              23.1951      31858
# ...             ...            ...                  ...        ...
# 858661            1              0               8.3025      31858
# 858663            1              0               8.3025      31858
# 858665            1              0               8.3025      31858
# 858695            1              0               8.3025      31858
# 858697            1              0               8.3025      31858
#
#                           stop_name  stop_desc   stop_lat   stop_lon  zone_id  \
# 59565   PORT AUTHORITY BUS TERMINAL        NaN  40.756209 -73.991001        0
# 59607   PORT AUTHORITY BUS TERMINAL        NaN  40.756209 -73.991001        0
# 59649   PORT AUTHORITY BUS TERMINAL        NaN  40.756209 -73.991001        0
# 59691   PORT AUTHORITY BUS TERMINAL        NaN  40.756209 -73.991001        0
# 59733   PORT AUTHORITY BUS TERMINAL        NaN  40.756209 -73.991001        0
# ...                             ...        ...        ...        ...      ...
# 858661  PORT AUTHORITY BUS TERMINAL        NaN  40.756209 -73.991001        0
# 858663  PORT AUTHORITY BUS TERMINAL        NaN  40.756209 -73.991001        0
# 858665  PORT AUTHORITY BUS TERMINAL        NaN  40.756209 -73.991001        0
# 858695  PORT AUTHORITY BUS TERMINAL        NaN  40.756209 -73.991001        0
# 858697  PORT AUTHORITY BUS TERMINAL        NaN  40.756209 -73.991001        0
#
#         route_id  service_id            trip_headsign  direction_id  block_id  \
# 59565          3           1  107 NEW YORK-Exact Fare             0  107HL002
# 59607          3           1  107 NEW YORK-Exact Fare             0  107HL005
# 59649          3           1  107 NEW YORK-Exact Fare             0  107HL004
# 59691          3           1  107 NEW YORK-Exact Fare             0  107HL006
# 59733          3           1  107 NEW YORK-Exact Fare             0  107HL001
# ...          ...         ...                      ...           ...       ...
# 858661        99           2  355 NEW YORK-Exact Fare             0  355ML003
# 858663        99           2  355 NEW YORK-Exact Fare             0  355ML004
# 858665        99           2  355 NEW YORK-Exact Fare             0  355ML004
# 858695        99           3  355 NEW YORK-Exact Fare             0  127ML016
# 858697        99           3  355 NEW YORK-Exact Fare             0  320ML018
#
#         shape_id
# 59565         74
# 59607         74
# 59649         74
# 59691         74
# 59733         74
# ...          ...
# 858661      1615
# 858663      1615
# 858665      1615
# 858695      1617
# 858697      1617
#
# [6219 rows x 20 columns]

# %% [markdown]
# ### Steps
#
# * Get `stop_sequence` for each `trip_id` where `stop_id=43274` (PABT)
# * For each `trip_id`, get `stop_sequence-1`

# %%
from dateutil.parser import parse as dt_parse

nonstop_stops=None

for trip_id, trip_stops in stop_times_with_details.groupby('trip_id'):
    if final_stop_id not in trip_stops["stop_id"].values:
        continue
    #trip_stops["arrival_time"]=pd.to_datetime(trip_stops["arrival_time"], format='%H:%M:%S', errors='coerce')
    #trip_stops["departure_time"]=pd.to_datetime(trip_stops["departure_time"], format='%H:%M:%S', errors='coerce')
    #print(trip_stops)
    start=trip_stops.tail(3).head(1)
    stop=trip_stops.tail(1)
    try:
        start["duration_in_minutes"]=(dt_parse(stop["arrival_time"].iloc[0])-dt_parse(start["departure_time"].iloc[0])).total_seconds()/60
    except:
        #print(start)
        #print(stop)
        continue # skip
    #display(trip_stops)
    #print(start)
    if nonstop_stops is None:
        nonstop_stops = start
    else:
        nonstop_stops = pd.concat([nonstop_stops, start])
    
display(nonstop_stops.query('departure_time > "06:00:00" and departure_time < "10:00:00"'))
# Out:
#         trip_id arrival_time departure_time  stop_id  stop_sequence  \
# 59563      1064     06:37:00       06:37:00    12120             40
# 59605      1065     07:07:00       07:07:00    12120             40
# 59647      1066     07:37:00       07:37:00    12120             40
# 59689      1067     08:07:00       08:07:00    12120             40
# 59731      1068     08:37:00       08:37:00    12120             40
# ...         ...          ...            ...      ...            ...
# 834541    17388     06:25:00       06:25:00    39684              1
# 834544    17389     06:53:00       06:53:00    39684              1
# 834547    17390     07:08:00       07:08:00    39684              1
# 834550    17391     07:29:00       07:29:00    39684              1
# 834553    17392     08:07:00       08:07:00    39684              1
#
#         pickup_type  drop_off_type  shape_dist_traveled  stop_code  \
# 59563             0              0               9.3388      18888
# 59605             0              0               9.3388      18888
# 59647             0              0               9.3388      18888
# 59689             0              0               9.3388      18888
# 59731             0              0               9.3388      18888
# ...             ...            ...                  ...        ...
# 834541            0              0               0.0000      27848
# 834544            0              0               0.0000      27848
# 834547            0              0               0.0000      27848
# 834550            0              0               0.0000      27848
# 834553            0              0               0.0000      27848
#
#                                 stop_name  ...   stop_lat   stop_lon  zone_id  \
# 59563   NORTH AREA TRANS CENTER - PORT ST  ...  40.707739 -74.160031       73
# 59605   NORTH AREA TRANS CENTER - PORT ST  ...  40.707739 -74.160031       73
# 59647   NORTH AREA TRANS CENTER - PORT ST  ...  40.707739 -74.160031       73
# 59689   NORTH AREA TRANS CENTER - PORT ST  ...  40.707739 -74.160031       73
# 59731   NORTH AREA TRANS CENTER - PORT ST  ...  40.707739 -74.160031       73
# ...                                   ...  ...        ...        ...      ...
# 834541      WAYNE ROUTE 23 TRANSIT CENTER  ...  40.900867 -74.255823        0
# 834544      WAYNE ROUTE 23 TRANSIT CENTER  ...  40.900867 -74.255823        0
# 834547      WAYNE ROUTE 23 TRANSIT CENTER  ...  40.900867 -74.255823        0
# 834550      WAYNE ROUTE 23 TRANSIT CENTER  ...  40.900867 -74.255823        0
# 834553      WAYNE ROUTE 23 TRANSIT CENTER  ...  40.900867 -74.255823        0
#
#         route_id  service_id            trip_headsign direction_id  block_id  \
# 59563          3           1  107 NEW YORK-Exact Fare            0  107HL002
# 59605          3           1  107 NEW YORK-Exact Fare            0  107HL005
# 59647          3           1  107 NEW YORK-Exact Fare            0  107HL004
# 59689          3           1  107 NEW YORK-Exact Fare            0  107HL006
# 59731          3           1  107 NEW YORK-Exact Fare            0  107HL001
# ...          ...         ...                      ...          ...       ...
# 834541        95           3     324 NEW YORK EXPRESS            0  191WY007
# 834544        95           3     324 NEW YORK EXPRESS            0  194WY002
# 834547        95           3     324 NEW YORK EXPRESS            0  194WY007
# 834550        95           3     324 NEW YORK EXPRESS            0  194WY020
# 834553        95           3     324 NEW YORK EXPRESS            0  191WY026
#
#        shape_id  duration_in_minutes
# 59563        74                 20.0
# 59605        74                 20.0
# 59647        74                 20.0
# 59689        74                 20.0
# 59731        74                 20.0
# ...         ...                  ...
# 834541     1566                 38.0
# 834544     1566                 38.0
# 834547     1566                 38.0
# 834550     1566                 38.0
# 834553     1566                 38.0
#
# [2394 rows x 21 columns]

# %%
nonstop_stops.to_csv("express_bus_stops.csv", index=False)

# %%
from dateutil.parser import parse as dt_parse
(dt_parse("06:57:00")-dt_parse("06:36:00")).total_seconds()/60
# Out:
# 21.0
